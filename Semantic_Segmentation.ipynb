# %% [markdown]
# <a href="https://colab.research.google.com/github/cristianmiholca/OrderManagement/blob/master/Semantic_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
import os
import torch
from google.colab import drive
import gc

# %%
# branch = 'test_fixes'
# branch = 'infrared_dataset'
# branch = 'segnet_debug'
# branch = 'debug_kitti'
branch = 'master'
root_dir = '/content/'
project_dir = os.path.join(root_dir, 'Semantic-Segmentation')
data_dir = os.path.join(project_dir, 'data')
camvid_zip_path = '/content/drive/MyDrive/Colab\ Notebooks/datasets/camvid.zip'
kitti_zip_path = '/content/drive/MyDrive/Colab\ Notebooks/datasets/kitti.zip'
infrared_zip_path = '/content/drive/MyDrive/Colab\ Notebooks/datasets/infrared.zip'
checkpoint_save_dir = '/content/drive/MyDrive/Colab\ Notebooks/Checkpoints'
camvid_dataset_dir = os.path.join(data_dir, 'CamVid')
kitti_dataset_dir = os.path.join(data_dir, 'data_road')
infrared_dataset_dir = os.path.join(data_dir, 'InfraRed')

# %%
branch = 'master'
root_dir = '/content/'
project_dir = os.path.join(root_dir, 'Semantic-Segmentation')
data_dir = os.path.join(project_dir, 'data')
camvid_zip_path = '/content/drive/MyDrive/Colab\ Notebooks/datasets/camvid.zip'
infrared_zip_path = '/content/drive/MyDrive/Colab\ Notebooks/datasets/infrared.zip'
checkpoint_save_dir = '/content/drive/MyDrive/Colab\ Notebooks/Checkpoints'
camvid_dataset_dir = os.path.join(data_dir, 'CamVid')
infrared_dataset_dir = os.path.join(data_dir, 'InfraRed')

# %%
# %cd $root_dir
if os.path.isdir(project_dir):
    # %rm -rf $project_dir
torch.cuda.empty_cache()
# Out:
# /content

# %%
if not os.path.isdir(project_dir):
    # !git clone -b $branch --single-branch https://github.com/cristianmiholca/Semantic-Segmentation.git
drive.mount('/content/drive')
if not os.path.isdir(data_dir):
    # %mkdir $data_dir
if not os.path.isdir(camvid_dataset_dir):
  # !unzip -q $camvid_zip_path -d $data_dir
if not os.path.isdir(kitti_dataset_dir):
  # !unzip -q $kitti_zip_path -d $data_dir
if not os.path.isdir(infrared_dataset_dir):
  # !unzip -q $infrared_zip_path -d $data_dir
# %cd $project_dir
# Out:
# Cloning into 'Semantic-Segmentation'...
# remote: Enumerating objects: 360, done.
# remote: Counting objects: 100% (186/186), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 360 (delta 112), reused 102 (delta 64), pack-reused 174
# Receiving objects: 100% (360/360), 333.69 KiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (209/209), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/Semantic-Segmentation

# %%
if not os.path.isdir(project_dir):
    # !git clone -b $branch --single-branch https://github.com/cristianmiholca/Semantic-Segmentation.git
drive.mount('/content/drive')
if not os.path.isdir(data_dir):
    # %mkdir $data_dir
if not os.path.isdir(camvid_dataset_dir):
  # !unzip -q $camvid_zip_path -d $data_dir
if not os.path.isdir(infrared_dataset_dir):
  # !unzip -q $infrared_zip_path -d $data_dir
# %cd $project_dir
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/Semantic-Segmentation

# %%
# !python ./main.py -h
# Out:
# usage: main.py [-h] [--device DEVICE] [--width WIDTH] [--height HEIGHT]
#                [--epochs EPOCHS] [--batch-size BATCH_SIZE]
#                [--learning-rate LEARNING_RATE] [--workers WORKERS]
#                [--weight-decay WEIGHT_DECAY]
#                [--dataset {camvid,kitti,infrared}] [--dataset-dir DATASET_DIR]
#                [--model {pspnet,unet,segnet}] [--tqdm [TQDM]] [--name NAME]
#                [--save-dir SAVE_DIR] [--load-model [LOAD_MODEL]]
#                [--resume-training [RESUME_TRAINING]] [--data-aug [DATA_AUG]]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --device DEVICE       Device on which the network will be trained. Default:
#                         cuda
#   --width WIDTH         The width of the image. Default: 512
#   --height HEIGHT       The width of the image. Default: 512
#   --epochs EPOCHS, -e EPOCHS
#                         The number of epochs. Default: 100
# ...

# %% [markdown]
# **CamVid + UNet Script**

# %%
# %run './main.py' --model unet \
#                  --name 'UNet' \
#                  --dataset camvid \
#                  --dataset-dir $camvid_dataset_dir \
#                  --epochs 200 \
#                  --workers 2 \
#                  --learning-rate 0.0001 \
#                  --batch-size 4 \
#                  --save-dir $checkpoint_save_dir \
#                  --resume-training "True"

# %% [markdown]
# **CamVid + PSPNet Script**

# %%
# %run './main.py' --model pspnet \
                 --name 'PSPNet' \
                 --dataset camvid \
                 --dataset-dir $camvid_dataset_dir \
                 --epochs 200 \
                 --workers 1 \
                 --learning-rate 0.0001 \
                 --batch-size 4 \
                 --save-dir $checkpoint_save_dir \
                 --resume-training "True"
# Out:
# 1.9.0+cu102
#
# Training...
#
# PspNet(
#   (layer0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
# ...

# %% [markdown]
# **Kitti + UNet Script**

# %%
# %run './main.py' --model unet \
#                  --name 'UNet' \
#                  --dataset kitti \
#                  --dataset-dir $kitti_dataset_dir \
#                  --epochs 200 \
#                  --workers 2 \
#                  --learning-rate 0.0001 \
#                  --batch-size 4 \
#                  --save-dir $checkpoint_save_dir \
#                  --resume-training "True"

# %% [markdown]
# **Kitti + PSPNet Script**

# %%
# %run './main.py' --model pspnet \
#                  --name 'PSPNet' \
#                  --dataset kitti \
#                  --dataset-dir $kitti_dataset_dir \
#                  --epochs 200 \
#                  --workers 2 \
#                  --learning-rate 0.0001 \
#                  --batch-size 4 \
#                  --save-dir $checkpoint_save_dir \
#                  --resume-training "True"

# %% [markdown]
# **InfraRed + UNet Script**

# %%
# %run './main.py' --model unet \
#                  --name 'UNet' \
#                  --dataset infrared \
#                  --dataset-dir $infrared_dataset_dir \
#                  --epochs 200 \
#                  --workers 2 \
#                  --learning-rate 0.0001 \
#                  --batch-size 4 \
#                  --save-dir $checkpoint_save_dir \
#                  --resume-training "True"

# %% [markdown]
# **InfraRed + PSPNet Script**

# %%
# %run './main.py' --model pspnet \
#                  --name 'PSPNet' \
#                  --dataset infrared \
#                  --dataset-dir $infrared_dataset_dir \
#                  --epochs 200 \
#                  --workers 2 \
#                  --learning-rate 0.0001 \
#                  --batch-size 4 \
#                  --save-dir $checkpoint_save_dir \
#                  --resume-training "True"
